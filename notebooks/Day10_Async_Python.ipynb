# %% [markdown]
# # Day 10 - Async Python (doing many slow things at once)
# Vidya Sankalp | Applied GenAI Engineering
#
# > **This day builds directly on Day 08 and Day 09.** On Day 08 you queried a **Postgres database**. On Day 09 you called **real APIs** over HTTP (DummyJSON and OpenAI). Both of those are *slow* - they make your program wait. Today you learn to do many of those slow things **at the same time**.
#
# > **No pretend waiting.** The slow work here is the real database queries and real HTTP calls you already know - not a fake `sleep()`. That is the whole reason we taught database and HTTP first.
#
# > **What you'll learn:** why waiting is slow -> `async`/`await` -> `httpx.AsyncClient` -> `asyncio.gather` (many at once) -> handling failures -> background work -> talking to Postgres the async way (`asyncpg`) and the 'use what you have' way (`to_thread` + your Day 08 code) -> the mailbox (`Queue`, how your agents work), the doorbell (`Event`), the bouncer (`Semaphore`) -> streaming an AI reply word by word.
#
# > **You need internet** for the HTTP/OpenAI cells (they call real servers), and the Postgres cells need a running database (same `.env` as Day 08). Each part says what it needs, and skips cleanly if it's not there.
#
# > **Jupyter note:** a notebook already runs an event loop, so we use **top-level `await`** in cells. In a real `.py` file you'd wrap the start in `asyncio.run(main())` (shown at the end).

# %% [markdown]
# ---

# %% [markdown]
# ## 0 - One-time setup
#
# We need `httpx` (Day 09) and, for the async database part, `asyncpg`. Install once if needed.

# %%
# Run once if these libraries aren't installed yet. Remove the # to run it.
#   httpx   = make HTTP calls (from Day 09)
#   asyncpg = talk to Postgres the async way (used in section 5)
# !pip install -q httpx asyncpg python-dotenv

import asyncio   # asyncio = Python's built-in toolkit for doing many waiting-jobs at once
import httpx     # httpx    = the HTTP tool from Day 09 (it also has an async version)
import time      # time     = a stopwatch, to measure how long things take
import os        # os       = used later to read database settings from your environment

BASE = 'https://dummyjson.com'      # the same real API server we used on Day 09
print('Ready.')

# %% [markdown]
# ---

# %% [markdown]
# ## 1 - The Problem: Slow Things, One After Another
#
# Remember the end of Day 09? Five slow calls, one after another, took about 2.5 seconds. Let's feel that pain again with **real HTTP calls** - we ask DummyJSON for 5 products, and we add `?delay=500` so each one takes about half a second (like a real, slightly slow server).

# %%
# The SLOW way: fetch 5 products one after another (ordinary, NON-async httpx from Day 09).
start = time.perf_counter()              # perf_counter() = a precise stopwatch reading, in seconds
titles = []
for pid in [1, 2, 3, 4, 5]:              # do each id in turn
    # params={'delay': 500}  ->  ask the server to wait 500 milliseconds (half a second) before
    #                            replying, so each call is realistically 'slow'.
    # timeout=15.0           ->  wait at most 15 seconds for each reply before giving up.
    r = httpx.get(f'{BASE}/products/{pid}', params={'delay': 500}, timeout=15.0)
    titles.append(r.json()['title'])     # pull the title out of each reply
print('Got:', titles)
# Because each call must FINISH before the next one STARTS, the half-seconds add up:
print(f'One after another took {time.perf_counter()-start:.1f}s  (~5 x 0.5s = ~2.5s)')

# %% [markdown]
# Every call had to *finish* before the next one *started*. But while we wait for DummyJSON to reply, our program is doing nothing useful. Async lets all 5 waits happen together.

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - The Two New Words: `async` and `await`
#
# | Word | Plain meaning |
# |------|---------------|
# | `async def` | marks a function as the 'smart waiting' kind - it can pause and let other work happen |
# | `await` | 'I have to wait here - go do something else useful, come back when this is ready' |
#
# For HTTP, the async version of the Day 09 client is **`httpx.AsyncClient`**. Same calls (`.get`, `.post`), but you `await` them, and you open it with `async with` so it cleans up after itself.

# %%
# The async version of the Day 09 client is httpx.AsyncClient. Three differences to notice:
#   1) the function is defined with 'async def' (it's the 'smart waiting' kind)
#   2) we open the client with 'async with' (it cleans itself up when the block ends)
#   3) we put 'await' before the call (pause here, let other work run while we wait)
async def get_one_title(pid):
    #   base_url=BASE  ->  set the home address once, so we can pass just '/products/1' to .get()
    #   timeout=15.0   ->  wait at most 15 seconds for a reply (same meaning as Day 09)
    async with httpx.AsyncClient(base_url=BASE, timeout=15.0) as client:
        r = await client.get(f'/products/{pid}')   # 'await' = run this and wait for the reply
        return r.json()['title']

# In a notebook we are allowed to use 'await' directly in a cell (Jupyter runs the event loop).
title = await get_one_title(1)
print('Product 1 is:', title)

# %% [markdown]
# > **Be honest about this single call:** on its own, it is **no faster** than the plain `httpx.get` from Day 09. We only have one thing happening, so there is nothing else for the event loop to do during the wait - it just waits. The benefit of async appears only when there are *several* things waiting at once, so their waits can overlap. That's the very next section.
#
# > (Also: opening a fresh `AsyncClient` for every call is wasteful - like dialling a new phone line each time. In the next section we open **one** client and reuse it for all the calls.)

# %% [markdown]
# ---

# %% [markdown]
# ## 3 - `asyncio.gather`: Many Calls at Once
#
# `asyncio.gather` takes several jobs, runs them **all at the same time**, and gives back all the answers together (in order). This is the fix for section 1's slow loop.

# %%
# The FAST way: open ONE client and fire all 5 requests together with asyncio.gather.
async def get_titles(pids):
    async with httpx.AsyncClient(base_url=BASE, timeout=15.0) as client:
        # an inner helper that fetches ONE product's title
        async def one(pid):
            r = await client.get(f'/products/{pid}', params={'delay': 500})  # same half-second delay
            return r.json()['title']
        # Build a list of jobs - one 'one(pid)' per id - WITHOUT awaiting them yet.
        # (Calling one(pid) here does NOT start it; it just makes a 'job ticket'. They start
        #  running only when gather schedules them below.)
        jobs = [one(pid) for pid in pids]
        # asyncio.gather(*jobs) starts them ALL together and waits for every one to finish.
        #   the *  unpacks the list  [one(1), one(2), ...]  into separate arguments for gather.
        #   the results come back as a list, in the SAME ORDER as the ids we passed in.
        #   While call #1 waits on the network, the event loop runs #2..#5 - their waits overlap.
        return await asyncio.gather(*jobs)

start = time.perf_counter()
titles = await get_titles([1, 2, 3, 4, 5])
print('Got:', titles)
# All 5 half-second waits overlapped, so the total is about ONE delay, not five added together:
print(f'All at once took {time.perf_counter()-start:.1f}s  (~0.5s, NOT ~2.5s!)')

# %% [markdown]
# Five slow calls finished in about the time of **one**, because the waits overlapped. Same real API, same data, just done concurrently. *This* is why async matters - and you can feel it because the waiting is real.

# %% [markdown]
# ---

# %% [markdown]
# ## 4 - When One Call Fails: `return_exceptions=True`
#
# Remember 404s from Day 09 (asking for a product that doesn't exist)? If one job in `gather` raises an error, it normally ruins the whole batch. Adding `return_exceptions=True` keeps the good results and hands you the errors as values instead.

# %%
async def get_or_error(pids):
    async with httpx.AsyncClient(base_url=BASE, timeout=15.0) as client:   # timeout: max 15s per call
        async def one(pid):
            r = await client.get(f'/products/{pid}')
            r.raise_for_status()   # turn a 404 (not found) into an error we can catch (from Day 09)
            return r.json()['title']
        # return_exceptions=True changes how gather handles a job that fails:
        #   - WITHOUT it: if any job raises, gather stops and raises that error immediately,
        #                 and you LOSE the results of the jobs that did succeed.
        #   - WITH it:    a failed job's error is placed into the results list AS A VALUE,
        #                 in that job's position, and every good result still comes back.
        return await asyncio.gather(
            *[one(pid) for pid in pids],
            return_exceptions=True,
        )

# id 99999 does not exist -> that one becomes an error; the others are fine.
results = await get_or_error([1, 2, 99999, 4])
for pid, res in zip([1, 2, 99999, 4], results):   # zip pairs each id with its matching result
    # isinstance(res, Exception) is True when this slot holds an error object instead of data.
    if isinstance(res, Exception):
        print(f'  product {pid}: FAILED ({type(res).__name__})')
    else:
        print(f'  product {pid}: {res}')

# %% [markdown]
# ---

# %% [markdown]
# ## 5 - Talking to Postgres the Async Way
#
# On Day 08 you used **`psycopg2`** to query Postgres. `psycopg2` is *blocking* - it freezes while waiting, which is bad in async code. There are two good ways to handle databases in async:
#
# | Way | What it is | When to use |
# |-----|------------|-------------|
# | **`asyncpg`** | a database library built *for* async Postgres | best choice for new async code |
# | **`to_thread` + your Day 08 `psycopg2` code** | run the old blocking code on a side worker | when you want to reuse code you already have |
#
# We'll show both. They need a running Postgres (the same `.env` as Day 08). If you don't have one connected, these cells just print a skip message.

# %% [markdown]
# ### 5a - The proper async way: `asyncpg`
#
# `asyncpg` mirrors what you already know: make a **pool** (a set of reusable connections), `acquire()` one with `async with`, and `await` your query. Postgres uses `$1, $2` for placeholders (instead of psycopg2's `%s`).

# %%
import os
# Try to import asyncpg and load your database settings from a .env file (same as Day 08).
try:
    import asyncpg                       # the async Postgres library
    from dotenv import load_dotenv       # reads a .env file into os.environ
    load_dotenv()                        # actually load it
    # all(...) is True only if BOTH DB_NAME and DB_USER are set (a quick 'is a DB configured?' check)
    HAVE_PG = all(os.environ.get(k) for k in ['DB_NAME', 'DB_USER'])
except Exception:
    HAVE_PG = False                      # if asyncpg isn't installed or .env is missing, skip DB cells
print('Postgres available:', HAVE_PG)

# %%
# We keep ONE pool of connections and reuse it. A 'pool' is a small set of ready-to-use database
# connections - opening a connection is slow, so we open a few once and share them.
_pg_pool = None                          # starts empty; we build it the first time we need it

async def get_pool():
    global _pg_pool                      # 'global' lets us update the module-level variable above
    if _pg_pool is None:                 # only build it once
        _pg_pool = await asyncpg.create_pool(   # create_pool opens the connections (so we await it)
            host     = os.environ.get('DB_HOST', 'localhost'),   # 2nd arg = default if not set
            port     = int(os.environ.get('DB_PORT', '5432')),   # int(...) because a port is a number
            database = os.environ.get('DB_NAME'),
            user     = os.environ.get('DB_USER'),
            password = os.environ.get('DB_PASSWORD'),
            min_size = 1,                # keep at least 1 connection ready
            max_size = 5,                # never open more than 5 at once
        )
    return _pg_pool

async def fetch_customer(customer_id):
    """Async version of Day 08's get_customer_by_id()."""
    pool = await get_pool()
    # 'async with pool.acquire()' BORROWS one connection and gives it back automatically at the end.
    async with pool.acquire() as conn:
        # await conn.fetchrow(SQL, value) runs the query and returns the FIRST matching row.
        #   $1  is the placeholder for the first value (Postgres style).
        #   Day 08's psycopg2 used %s; asyncpg uses $1, $2, $3, ...  Same idea: never glue values
        #   into SQL by hand (that risks SQL injection) - pass them separately and let the library do it.
        row = await conn.fetchrow(
            'SELECT * FROM customers WHERE customer_id = $1', customer_id)
    # asyncpg returns a 'Record' (a row). dict(row) turns it into a normal Python dictionary.
    return dict(row) if row else None    # None if no customer had that id

if HAVE_PG:
    one = await fetch_customer(1001)
    print('Fetched (async):', one)
else:
    print('(skipped - no Postgres connected)')

# %% [markdown]
# Now the payoff: fetch **several** customers **at once** with `gather`, exactly like we did for HTTP. Each lookup is a real database round-trip, and they overlap.

# %%
if HAVE_PG:
    start = time.perf_counter()
    # Fetch three customers AT ONCE. Each fetch is a real database round-trip; gather overlaps them,
    # exactly like it overlapped the HTTP calls earlier.
    customers = await asyncio.gather(
        fetch_customer(1001),
        fetch_customer(1002),
        fetch_customer(1003),
    )
    for c in customers:
        print('  ', c)
    print(f'Three real DB lookups together took {time.perf_counter()-start:.2f}s')
else:
    print('(skipped - no Postgres connected)')

# %% [markdown]
# ### 5b - The 'use what you already have' way: `to_thread`
#
# Maybe you already wrote blocking `psycopg2` functions on Day 08 and don't want to rewrite them. Here is the key idea, stated carefully:
#
# > `asyncio.to_thread` does **not** turn a sync function into an async one. The function stays exactly as it is - plain and blocking. What `to_thread` does is **run that blocking function on a separate worker thread**, so the freezing happens off to the side and your main event loop stays free. It then gives you back something you can `await`.
#
# So you keep your Day 08 function unchanged and just wrap the *call* in `await asyncio.to_thread(your_function, arg)`.
#
# | | What it is |
# |---|-----------|
# | your Day 08 function | a normal, blocking, **sync** function - unchanged |
# | `asyncio.to_thread(fn, arg)` | runs that blocking function on a **side worker thread** |
# | the result | something you can `await`, so it behaves nicely inside async code |

# %%
import psycopg2, psycopg2.extras

def get_customer_by_id_blocking(customer_id):
    """This is your Day 08 function, UNCHANGED - a plain, blocking, SYNC function."""
    conn = psycopg2.connect(             # psycopg2.connect = open a (blocking) DB connection
        host=os.environ.get('DB_HOST', 'localhost'),
        port=int(os.environ.get('DB_PORT', '5432')),
        dbname=os.environ.get('DB_NAME'),
        user=os.environ.get('DB_USER'),
        password=os.environ.get('DB_PASSWORD'),
    )
    # RealDictCursor makes each row come back as a dict instead of a plain tuple (Day 08).
    with conn.cursor(cursor_factory=psycopg2.extras.RealDictCursor) as cur:
        cur.execute('SELECT * FROM customers WHERE customer_id = %s', (customer_id,))  # %s = placeholder
        row = cur.fetchone()             # fetchone() = the first matching row (or None)
    conn.close()
    return dict(row) if row else None

async def fetch_customer_via_thread(customer_id):
    # IMPORTANT: to_thread does NOT turn the function above into an async function.
    # The function stays a normal, blocking, sync function - completely unchanged.
    # What to_thread does is RUN that blocking function on a separate worker thread, so the
    # blocking happens over there (harmlessly) and the main event loop stays free to run
    # other coroutines. It then gives us back something we can 'await'.
    #   to_thread(FUNCTION, ARG)  ->  pass the function and its argument SEPARATELY.
    #                                 Do NOT call it yourself - no parentheses on the function.
    #                                 (to_thread calls it for you, on the worker thread.)
    return await asyncio.to_thread(get_customer_by_id_blocking, customer_id)

if HAVE_PG:
    # Even though the underlying function is blocking, running each on its own worker thread
    # lets gather overlap their waits - so two lookups still happen at about the same time:
    rows = await asyncio.gather(
        fetch_customer_via_thread(1001),
        fetch_customer_via_thread(1002),
    )
    for r in rows: print('  ', r)
else:
    print('(skipped - no Postgres connected)')

# %% [markdown]
# > **Which should you use?** If a real async library exists for the job (like `asyncpg` for Postgres), prefer it - it's lighter and needs no extra threads. If you only have a blocking library (psycopg2, `requests`, `boto3`, some old SDK) and can't or don't want to rewrite it, `to_thread` is the escape hatch. Both are correct - now you know both.

# %% [markdown]
# ---

# %% [markdown]
# ### 5c - The four basic operations: INSERT, SELECT, UPDATE, DELETE (asyncpg)
#
# On Day 08 you did these four with psycopg2 and a cursor. asyncpg does the same four, but more directly - no cursor needed. There are just **two methods** to remember:
#
# | You want to... | asyncpg method | Day 08 (psycopg2) equivalent |
# |----------------|----------------|------------------------------|
# | **INSERT / UPDATE / DELETE** (change data, no rows to read back) | `await conn.execute(SQL, *values)` | `cur.execute(...)` then `conn.commit()` |
# | **SELECT** one row | `await conn.fetchrow(SQL, *values)` | `cur.execute(...)` then `cur.fetchone()` |
# | **SELECT** many rows | `await conn.fetch(SQL, *values)` | `cur.execute(...)` then `cur.fetchall()` |
#
# Two things to remember from section 5a:
# - Placeholders are `$1, $2, $3, ...` (Postgres style), **not** psycopg2's `%s`.
# - Always pass values **separately** (as extra arguments), never glue them into the SQL string - that's what keeps you safe from SQL injection.
#
# Below we run all four in order on a `customers` table. (Each cell is guarded so it skips with no database.)

# %%
# A full INSERT -> SELECT -> UPDATE -> SELECT -> DELETE walkthrough, asyncpg style.
# Every query borrows a connection from the pool with 'async with pool.acquire()'.

async def crud_demo():
    pool = await get_pool()

    # ---------- INSERT ----------
    async with pool.acquire() as conn:
        # conn.execute runs a statement that doesn't return rows (INSERT/UPDATE/DELETE).
        #   $1, $2, $3  ->  placeholders for the three values passed after the SQL.
        #   the values 9001, 'Test User', 'test@shop.com' fill $1, $2, $3 in order.
        # It returns a short status string like 'INSERT 0 1' (1 = one row inserted).
        status = await conn.execute(
            'INSERT INTO customers (customer_id, name, email) VALUES ($1, $2, $3)',
            9001, 'Test User', 'test@shop.com',
        )
        print('INSERT status:', status)

    # ---------- SELECT one ----------
    async with pool.acquire() as conn:
        # fetchrow returns the FIRST matching row as a Record (or None). dict(...) makes it a dict.
        row = await conn.fetchrow(
            'SELECT * FROM customers WHERE customer_id = $1', 9001)
        print('SELECT after insert:', dict(row) if row else None)

    # ---------- UPDATE ----------
    async with pool.acquire() as conn:
        # change the name of customer 9001. $1 = new name, $2 = which customer.
        status = await conn.execute(
            'UPDATE customers SET name = $1 WHERE customer_id = $2',
            'Updated User', 9001,
        )
        print('UPDATE status:', status)            # e.g. 'UPDATE 1' (1 row changed)

    # ---------- SELECT again (see the change) ----------
    async with pool.acquire() as conn:
        row = await conn.fetchrow(
            'SELECT * FROM customers WHERE customer_id = $1', 9001)
        print('SELECT after update:', dict(row) if row else None)

    # ---------- DELETE ----------
    async with pool.acquire() as conn:
        status = await conn.execute(
            'DELETE FROM customers WHERE customer_id = $1', 9001)
        print('DELETE status:', status)            # e.g. 'DELETE 1' (1 row removed)

    # ---------- SELECT many (confirm it's gone / show remaining) ----------
    async with pool.acquire() as conn:
        # fetch returns ALL matching rows as a list of Records. LIMIT 3 keeps the printout small.
        rows = await conn.fetch('SELECT * FROM customers ORDER BY customer_id LIMIT 3')
        print(f'SELECT many - first {len(rows)} customers still in the table:')
        for r in rows:
            print('   ', dict(r))

if HAVE_PG:
    await crud_demo()
else:
    print('(skipped - no Postgres connected)')

# %% [markdown]
# > **Recap of the two methods:** use `await conn.execute(...)` for INSERT / UPDATE / DELETE (it returns a status string, not rows), and `await conn.fetchrow(...)` / `await conn.fetch(...)` for SELECT (one row / many rows). Same four operations you learned on Day 08 - just async, with `$1` placeholders and no cursor.

# %% [markdown]
# ## 6 - Mixing It All: Fetch (HTTP) + Validate (Pydantic from Day 08)
#
# Let's combine all three days: fetch products concurrently over HTTP (Day 09 + today), then validate each one with a **Pydantic model** (Day 08). Clean data, fetched fast.

# %%
from pydantic import BaseModel, Field

# A Pydantic model just like Day 08's ProductRecord. It describes the shape we EXPECT,
# and validates/cleans the data the API gives us.
class ProductRecord(BaseModel):
    id: int                              # must be a whole number
    title: str                           # must be text
    category: str
    price: float = Field(gt=0)           # must be a number greater than 0 (gt = 'greater than')

async def fetch_validated(pids):
    async with httpx.AsyncClient(base_url=BASE, timeout=15.0) as client:
        async def one(pid):
            r = await client.get(f'/products/{pid}')
            # model_validate(dict) checks the API data against the model and returns a clean object.
            # If a field were missing or the wrong type, it would raise a clear error here.
            return ProductRecord.model_validate(r.json())
        return await asyncio.gather(*[one(pid) for pid in pids])   # fetch + validate, all at once

products = await fetch_validated([1, 2, 3])
for p in products:
    # p is now a ProductRecord object, so we read fields with a dot:  p.id, p.title, ...
    print(f'  #{p.id}  {p.title:<28} {p.category:<14} ${p.price}')

# %% [markdown]
# ---

# %% [markdown]
# ## 7 - Background Work: `asyncio.create_task`
#
# `gather` waits for everything. But sometimes you want to **start a job and keep going** without waiting for it - and let it finish *while you do other useful work*.
#
# The real example: a user sends a message. You want to **save it to the database**, but the user shouldn't wait for that save - they should get their reply as fast as possible. So you fire the save into the **background** with `asyncio.create_task(...)`, then do the **foreground** work (generating the reply) at the same time. The save overlaps the reply, so it costs no extra time.
#
# | What you write | What it does |
# |----------------|--------------|
# | `task = asyncio.create_task(job())` | start `job()` running NOW, in the background; don't wait |
# | `... other work here ...` | this runs immediately, *while* the background job is going |
# | `await task` | later, wait for the background job to finish (if it hasn't already) |
#
# **The key:** `create_task` only helps if there is real foreground work *between* starting the task and awaiting it. That gap is where the overlap - and the time saving - lives.

# %%
import time

log = []                                  # pretend this is our database

async def save_message(text):
    """BACKGROUND job: write to the DB. Takes 0.3s. The user should NOT have to wait for this."""
    await asyncio.sleep(0.3)              # asyncio.sleep here stands in for a real DB write
    log.append(text)
    print(f'   [background] saved to DB: {text!r}')

async def generate_reply(message):
    """FOREGROUND job: the REAL work - figure out the answer. Takes 0.5s."""
    await asyncio.sleep(0.5)              # stands in for real work: a DB query, an LLM call, etc.
    return 'Your order is on its way!'

async def handle_user(message):
    start = time.perf_counter()

    # STEP 1: start the DB save in the BACKGROUND. create_task starts it running immediately
    # and hands back a 'task' handle WITHOUT waiting. We do NOT await it here - so the next
    # line runs straight away while the save quietly runs on its own.
    save_job = asyncio.create_task(save_message(message))

    # STEP 2: do the FOREGROUND work - generate the reply (0.5s). Crucially, the background
    # save (0.3s) is running AT THE SAME TIME as this. Their waits overlap.
    reply = await generate_reply(message)
    print(f'Reply ready for user: {reply!r}')

    # STEP 3: the save was happening the whole time we built the reply. Before we finish,
    # 'await save_job' makes sure it actually completed (so we never lose data on shutdown).
    # By now it's almost certainly already done.
    await save_job

    # Total is about 0.5s (the LONGER job), NOT 0.8s (0.3 + 0.5 added up) -
    # because the 0.3s save 'hid inside' the 0.5s reply.
    print(f'Done in {time.perf_counter()-start:.1f}s   (~0.5s, NOT 0.8s!)')

await handle_user('Where is my order #3042?')
print('DB now holds:', log)

# %% [markdown]
# > **Watch the timing:** the whole thing took ~0.5s, not 0.8s. The 0.3s save ran *inside* the 0.5s reply window - that overlap is the entire benefit.
#
# > **What NOT to do:** if you `await` the task *immediately* after creating it, like this:
# > ```python
# > save_job = asyncio.create_task(save_message(message))
# > await save_job                 # waiting right away!
# > reply = await generate_reply(message)
# > ```
# > ...then there's no foreground work happening during the save, so you lose all the benefit - it now takes ~0.8s again, exactly as if you never used `create_task`. The trick is to put your other work *between* the `create_task` and the `await`.

# %% [markdown]
# > **About the `sleep`s here:** we use `asyncio.sleep` to stand in for real work (a DB write, an LLM call) just to keep the example short and runnable without a database. In your real project, `save_message` would be an actual async DB insert and `generate_reply` would be the real supervisor/LLM call - but the *timing behaviour* (the save hiding inside the reply) is exactly the same.

# %% [markdown]
# ---

# %% [markdown]
# ## 8 - The Mailbox: `asyncio.Queue` (this is how your agents work)
#
# This section explains something at the very heart of *your own project*. Every agent you build has this shape:
#
# ```python
# async def execute(self, context, event_queue):
#     await event_queue.enqueue_event(task)      # the agent drops a note into the mailbox
# ```
#
# What is that `event_queue`? It is a **mailbox**. Picture two people working at the same time:
#
# - One person (your **agent**) keeps **dropping notes** into the mailbox: 'started', 'working', 'here is the result'.
# - Another person (the **framework**) keeps **taking notes out** and reading each one to the user.
#
# They never block each other - the mailbox sits in between. Python's name for this mailbox is **`asyncio.Queue`**:
#
# | What you write | What it does |
# |----------------|--------------|
# | `mailbox = asyncio.Queue()` | make an empty mailbox |
# | `await mailbox.put(note)` | the producer drops a note in |
# | `await mailbox.get()` | the consumer takes the next note out (waits if the box is empty) |
#
# Learn this little `Queue` and you understand the `EventQueue` in your real agents - they are the same idea.

# %%
# We use a special 'FINISHED' marker so the reader knows when no more notes are coming.
# object() just makes a unique one-of-a-kind value we can compare against with 'is'.
FINISHED = object()

async def the_agent(question, mailbox):
    """The PRODUCER - drops notes in. This mirrors your agent's execute(self, context, event_queue)."""
    #   mailbox.put(X)  ->  add X to the mailbox. We 'await' it because the mailbox could be full
    #                       (it can have a size limit); awaiting lets it wait politely if so.
    await mailbox.put({'type': 'status', 'text': 'got the question'})
    await asyncio.sleep(0.1)                       # pretend doing a bit of work
    await mailbox.put({'type': 'status', 'text': 'looking in the database'})
    await asyncio.sleep(0.1)
    await mailbox.put({'type': 'result', 'text': 'Electronics: $1.24M'})
    await mailbox.put(FINISHED)                    # last note: 'I'm done, no more coming'

async def the_reader(mailbox):
    """The CONSUMER - takes notes out. This mirrors the framework that streams events to the user."""
    while True:                                    # keep reading until we see FINISHED
        note = await mailbox.get()                 # take the next note (waits here if box is empty)
        if note is FINISHED:                       # the agreed 'stop' marker
            break
        print('   reader sees:', note)

# Make the mailbox, then run the dropper and the reader AT THE SAME TIME (gather).
mailbox = asyncio.Queue()
await asyncio.gather(
    the_agent('top category?', mailbox),           # keeps putting notes in
    the_reader(mailbox),                           # keeps taking notes out
)

# %% [markdown]
# The producer and the reader ran **together**, connected only by the mailbox - the producer never had to wait for the reader to catch up.
#
# **The bridge to your project:** swap the toy `asyncio.Queue` for the A2A `EventQueue`, and `mailbox.put(...)` for `event_queue.enqueue_event(...)`, and the code above *is* your agent's `execute(...)` method. The 'reader' is the A2A framework, which turns each note into a streamed event the user sees (the same SSE streaming idea from Day 09). Now that whole mechanism is no longer magic.

# %% [markdown]
# ---

# %% [markdown]
# ## 9 - The Doorbell: `asyncio.Event` (a signal with no data)
#
# A **mailbox** (`Queue`) passes *notes* - actual data. Sometimes you don't need to pass data at all; you just need to send a **signal**: 'it's ready now!'. That is an **`asyncio.Event`** - think of it as a **doorbell**.
#
# - One part of your program **waits** for the bell (`await event.wait()`).
# - Another part **rings** it (`event.set()`), and everyone who was waiting wakes up.
#
# | What you write | What it does |
# |----------------|--------------|
# | `bell = asyncio.Event()` | make a doorbell, starts 'not rung' |
# | `await bell.wait()` | pause here until the bell is rung |
# | `bell.set()` | ring the bell - wakes up everyone waiting |
# | `bell.is_set()` | check if it's already been rung (True/False) |
#
# This is the idea behind 'the data is loaded now' or 'the task is ready' flags - one part announces, others wait for the announcement.

# %%
# Make a doorbell. It starts in the 'not rung yet' state.
bell = asyncio.Event()

async def the_guest():
    print('   guest: waiting by the door...')
    await bell.wait()                # PAUSE right here until someone rings the bell
    print('   guest: heard the bell, coming in!')

async def the_host():
    await asyncio.sleep(0.2)         # the host is busy for a moment
    print('   host: ringing the doorbell')
    bell.set()                       # RING - this wakes up the guest waiting above

# Run both at once: the guest waits, the host rings after 0.2s, then the guest proceeds.
await asyncio.gather(the_guest(), the_host())

# %% [markdown]
# Notice the guest's code simply *paused* at `await bell.wait()` and continued the instant the host called `bell.set()`. No data changed hands - just a signal. Use a **Queue** when you need to pass *things*; use an **Event** when you only need to say *'now!'*.

# %% [markdown]
# ---

# %% [markdown]
# ## 10 - The Bouncer: `asyncio.Semaphore` (only N at a time)
#
# `gather` happily starts *all* your jobs at once. But sometimes you must **not** do too many at once - for example, an AI API might say 'no more than 5 requests at the same time', or you might not want to hammer a database with 100 simultaneous queries.
#
# An **`asyncio.Semaphore`** is a **bouncer at a club door**: it lets only a fixed number of jobs 'inside' at once. The rest wait politely in line until a spot frees up.
#
# | What you write | What it does |
# |----------------|--------------|
# | `bouncer = asyncio.Semaphore(2)` | allow at most 2 inside at once |
# | `async with bouncer:` | take a spot (or wait here if all spots are full); free it at the end |
#
# > Your current project does not use a Semaphore yet - but the moment you need to rate-limit calls to an LLM or an external API, this is the tool. So it's worth knowing now.

# %%
# Make a bouncer that allows only 2 jobs inside at the same time.
bouncer = asyncio.Semaphore(2)           # the number 2 = how many are allowed at once

async def one_call(n):
    # 'async with bouncer:' tries to take one of the 2 spots.
    #   - if a spot is free, it enters immediately
    #   - if both spots are taken, it WAITS here until one frees up
    # When the block ends, the spot is automatically given back to the next waiter.
    async with bouncer:
        await asyncio.sleep(0.2)         # pretend this call takes 0.2 seconds
        return f'call {n} done'

start = time.perf_counter()
# Start 5 calls at once with gather - BUT the bouncer only lets 2 run at a time.
results = await asyncio.gather(*[one_call(i) for i in range(5)])
elapsed = time.perf_counter() - start
print(results)
# 5 calls, 2 at a time, 0.2s each => they run in 3 'waves' (2 + 2 + 1) => about 0.6s,
# NOT 0.2s (which is what plain gather with no limit would give).
print(f'Took {elapsed:.1f}s  (5 calls, max 2 at a time => 3 waves => ~0.6s)')

# %% [markdown]
# Without the bouncer, all 5 calls would run together and finish in ~0.2s. With `Semaphore(2)`, only 2 run at a time, so it takes ~0.6s - which is exactly what you want when a server says 'don't send more than 2 at once'. You trade a little speed for staying within the limit.

# %% [markdown]
# ## 11 - Streaming an AI Reply, Word by Word
#
# On Day 09 you saw the OpenAI API send its answer in pieces (`data: ...` lines), and we *received* them. Async is what makes streaming smooth. Here we read an OpenAI stream with `httpx.AsyncClient` and `async for`, printing each word as it arrives.
#
# > Needs your `OPENAI_API_KEY` (from Day 09). Skips cleanly if it isn't set.

# %%
OPENAI_KEY = os.environ.get('OPENAI_API_KEY')   # your key, read from the environment (Day 09)
OPENAI_URL = 'https://api.openai.com/v1/chat/completions'

async def stream_ai_reply(question):
    headers = {'Authorization': f'Bearer {OPENAI_KEY}'}   # the auth header from Day 09
    body = {
        'model': 'gpt-4o-mini',
        'messages': [{'role': 'user', 'content': question}],
        'stream': True,                  # ask OpenAI to send the answer piece by piece
    }
    #   timeout=30.0  ->  AI replies are slow, so allow up to 30 seconds (same as Day 09)
    async with httpx.AsyncClient(timeout=30.0) as client:
        # client.stream('POST', ...) keeps the connection open so we can read pieces as they arrive.
        async with client.stream('POST', OPENAI_URL, headers=headers, json=body) as resp:
            # 'async for' is the async cousin of a normal 'for' - it hands us each line the MOMENT
            # it arrives over the network, instead of waiting for the whole reply.
            async for line in resp.aiter_lines():
                if not line.startswith('data: '):
                    continue                          # skip lines that aren't data
                chunk = line[len('data: '):]          # remove the 'data: ' prefix
                if chunk == '[DONE]':                 # OpenAI sends this to mean 'finished'
                    break
                import json as _json
                # dig out the little piece of text this chunk carries (may be empty on some chunks)
                delta = _json.loads(chunk)['choices'][0]['delta']
                if 'content' in delta:
                    print(delta['content'], end='', flush=True)   # end='' so the words join up live
    print('\n(done)')

if OPENAI_KEY:
    await stream_ai_reply('List 3 quick benefits of a standing desk.')
else:
    print('(skipped - no OPENAI_API_KEY set)')

# %% [markdown]
# Notice `async for line in resp.aiter_lines()` - the async cousin of a normal `for`. It hands you each piece *as it arrives over the network*, so the words appear live. This is the receiving side of streaming; on the FastAPI day you'll build the *sending* side.

# %% [markdown]
# ---

# %% [markdown]
# ## 12 - Running Async in a Real `.py` File
#
# Jupyter let us `await` directly. In a normal script there's no event loop yet, so you start one with `asyncio.run(...)` - one line at the bottom.

# %%
reference = '''
import asyncio, httpx

async def main():
    async with httpx.AsyncClient(base_url="https://dummyjson.com") as client:
        r = await client.get("/products/1")
        print(r.json()["title"])

if __name__ == "__main__":
    asyncio.run(main())     # creates the loop, runs main(), closes it
'''
print(reference)

# %% [markdown]
# ---

# %% [markdown]
# ## Quick Recap - Day 10
#
# | Tool | In one plain sentence | Built on |
# |------|------------------------|----------|
# | `async def` / `await` | mark 'smart waiting' work and pause politely | - |
# | `httpx.AsyncClient` | the async version of Day 09's HTTP client | Day 09 |
# | `asyncio.gather(*jobs)` | run many slow calls at once, answers in order | Day 09 calls |
# | `return_exceptions=True` | keep good results, return errors as values | Day 09 404s |
# | `asyncpg` | query Postgres the proper async way (`$1` placeholders) | Day 08 DB |
# | `asyncio.to_thread(fn)` | reuse your Day 08 blocking `psycopg2` code safely | Day 08 DB |
# | Pydantic `model_validate` | validate the fetched data | Day 08 |
# | `asyncio.create_task(job)` | start work in the background, don't wait | - |
# | `asyncio.Queue` (put/get) | a mailbox passing notes between two parts | your agents' `EventQueue` |
# | `asyncio.Event` (wait/set) | a doorbell - a signal with no data | 'ready / done' flags |
# | `asyncio.Semaphore(n)` | a bouncer - only n jobs at a time | rate-limiting API/LLM calls |
# | `async for` + `aiter_lines` | read a stream piece by piece (AI reply) | Day 09 OpenAI |
# | `asyncio.run(main())` | start async in a real `.py` file | - |
#
# **Four things to remember:**
# 1. Async helps with **waiting** work (database, HTTP, AI) - exactly the slow things from Days 08 and 09.
# 2. `await` one line after another does **not** overlap - use `gather` to overlap.
# 3. For Postgres: `asyncpg` for new code, or `to_thread` to reuse your Day 08 psycopg2 code.
# 4. Streaming = reading pieces with `async for` as they arrive.
# 5. A **Queue** is a mailbox (your agents' `EventQueue`); an **Event** is a doorbell; a **Semaphore** is a bouncer that caps how many run at once.
#
# **Next - Day 11 (FastAPI):** you've now *called* APIs and made them fast. Next you *build* one - your own ShopSmart API that queries the database, calls the AI, and streams replies back.
